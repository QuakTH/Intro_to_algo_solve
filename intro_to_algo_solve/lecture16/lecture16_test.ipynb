# %% [markdown]
# # Dijkstra

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import modules

# %%
from intro_to_algo_solve.lecture16 import weighted_graph
from intro_to_algo_solve.lecture16.dijkstra import do_dijkstra

# %% [markdown]
# ## Test function

# %%
# graph_info = {
#     "A": [("B", 10), ("C", 5)],
#     "B": [("A", 10), ("D", 7)],
#     "C": [("A", 5), ("D", 2)],
#     "D": [("B", 7), ("C", 2)],
# }

graph_info = {
    "A": [("B", 10), ("C", 3)],
    "B": [("D", 2), ("C", 1)],
    "C": [("D", 8), ("B", 4), ("E", 2)],
    "D": [("E", 7)],
    "E": [("D", 9)],
}

# %%
g = weighted_graph.WeightedGraph(graph_info,True)

# %%
g.visualize()

# %%
do_dijkstra(g,'A')
# Out:
# ({'A': 0, 'B': 7, 'C': 3, 'D': 9, 'E': 5},
#  {'A': None, 'B': 'C', 'C': 'A', 'D': 'B', 'E': 'C'})
