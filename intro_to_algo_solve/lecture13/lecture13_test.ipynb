# %% [markdown]
# # Breadth First Search

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import modules

# %%
from intro_to_algo_solve.lecture13.bfs import breadth_first_search
from intro_to_algo_solve.data_structures.graph import Graph

# %% [markdown]
# ## Test function

# %%
g = Graph({"A": ["B", "C"], "B": ["A", "D"], "C": ["A", "D"], "D": ["B", "C"]})

# %%
g.visualize()

# %%
breadth_first_search(g,'A')
# Out:
# ({'A': 0, 'B': 1, 'C': 1, 'D': 2}, {'A': None, 'B': 'A', 'C': 'A', 'D': 'B'})

# %%
g = Graph(
    {
        "A": ["B", "C"],
        "B": ["A", "D"],
        "C": ["A", "D", "E"],
        "D": ["B", "C", "E"],
        "E": ["C", "D"],
    }
)

# %%
g.visualize()

# %%
breadth_first_search(g, 'B')
# Out:
# ({'B': 0, 'A': 1, 'D': 1, 'C': 2, 'E': 2},
#  {'B': None, 'A': 'B', 'D': 'B', 'C': 'A', 'E': 'D'})

# %%
breadth_first_search(g,'C')
# Out:
# ({'C': 0, 'A': 1, 'D': 1, 'E': 1, 'B': 2},
#  {'C': None, 'A': 'C', 'D': 'C', 'E': 'C', 'B': 'A'})

# %%
breadth_first_search(g,'E')
# Out:
# ({'E': 0, 'C': 1, 'D': 1, 'A': 2, 'B': 2},
#  {'E': None, 'C': 'E', 'D': 'E', 'A': 'C', 'B': 'D'})
