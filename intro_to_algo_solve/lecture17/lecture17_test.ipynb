# %% [markdown]
# # Bellman-Ford

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import modules

# %%
from intro_to_algo_solve.data_structures.graph import Graph
from intro_to_algo_solve.lecture17.bellman_ford import do_bellman_ford

# %% [markdown]
# ## Test function

# %%
graph_info = {
    "A": [("B", 10), ("C", 3)],
    "B": [("D", 2), ("C", 1)],
    "C": [("D", 8), ("B", 4), ("E", 2)],
    "D": [("E", 7)],
    "E": [("D", 9)],
}

# %%
g = Graph(graph_info,True)

# %%
g.visualize()

# %%
do_bellman_ford(g, "A")
# Out:
# ({'A': 0, 'B': 7, 'C': 3, 'D': 9, 'E': 5},
#  {'A': None, 'B': 'C', 'C': 'A', 'D': 'B', 'E': 'C'})

# %%
graph_info = {
    "A": [("B", -1), ("C", 4)],
    "B": [("D", 2), ("C", 3), ("E", 2)],
    "C": [],
    "D": [("B", 1), ("C", 5)],
    "E": [("D", -3)],
}

# %%
g = Graph(graph_info,True)

# %%
g.visualize()

# %%
do_bellman_ford(g, "D")
# Out:
# ({'A': inf, 'B': 1, 'C': 4, 'D': 0, 'E': 3},
#  {'A': None, 'B': 'D', 'C': 'B', 'D': None, 'E': 'B'})

# %%
graph_info = {
    "A": [("B", -1)],
    "B": [("C", 3)],
    "C": [("A", -5)],
}

# %%
g = Graph(graph_info,True)

# %%
g.visualize()

# %%
do_bellman_ford(g, "A")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 do_bellman_ford(g, "A")
#
# File ~/projects/Intro_to_algo_solve/intro_to_algo_solve/lecture17/bellman_ford.py:31, in do_bellman_ford(graph, start_node)
#      21         relax(
#      22             from_node,
#      23             to_node,
#    (...)
#      26             before_node_infos,
#      27         )
#      29 for (from_node, to_node), weight in graph.edge_weight_infos.items():
#      30     assert (
# ---> 31         min_weight_infos[to_node] <= min_weight_infos[from_node] + weight
#      32     ), "There is a negative weight cycle in the graph."
#      34 return min_weight_infos, before_node_infos
#
# AssertionError: There is a negative weight cycle in the graph.
